# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "/Users/kassyedwards/Desktop/API_HW//cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
print(cities)
# Out:
# ['awjilah', 'taolanaro', 'ilulissat', 'marcona', 'nanortalik', 'bredasdorp', 'cape town', 'saskylakh', 'busselton', 'longyearbyen', 'islamkot', 'bathsheba', 'broken hill', 'dunmore town', 'butaritari', 'qurbus', 'kapaa', 'stornoway', 'tecolutla', 'barrow', 'punta arenas', 'olafsvik', 'atuona', 'bethel', 'sao filipe', 'iqaluit', 'sitka', 'cumaribo', 'dikson', 'gao', 'vardo', 'rikitea', 'mataura', 'tsihombe', 'ushuaia', 'sungairaya', 'lompoc', 'kinkala', 'faanui', 'okha', 'puerto ayora', 'hilo', 'kaitangata', 'turukhansk', 'albany', 'winkler', 'asekeyevo', 'yellowknife', 'mrirt', 'manokwari', 'avarua', 'te anau', 'san patricio', 'honningsvag', 'hithadhoo', 'mar del plata', 'saint george', 'jamestown', 'airai', 'hermanus', 'nenjiang', 'tezu', 'barentsburg', 'pevek', 'nikolskoye', 'pitimbu', 'oistins', 'tabiauea', 'bluff', 'caiaponia', 'hambantota', 'vaitupu', 'ketchikan', 'castro', 'calvinia', 'hobart', 'port alfred', 'cidreira', 'belushya guba', 'esperance', 'qaanaaq', 'keti bandar', 'utiroa', 'mahebourg', 'solovetskiy', 'kahului', 'key largo', 'jaciara', 'saint-philippe', 'los llanos de aridane', 'vaini', 'elko', 'tchibanga', 'panlaitan', 'smirnykh', 'huangpi', 'port macquarie', 'kodinsk', 'samusu', 'bubaque', 'illoqqortoormiut', 'maua', 'manaus', 'meulaboh', 'mamallapuram', 'georgetown', 'port elizabeth', 'weihe', 'grand gaube', 'kodiak', 'khatanga', 'qaqortoq', 'sao joao da barra', 'nioro', 'warrnambool', 'tuktoyaktuk', 'xining', 'nemuro', 'teo', 'deputatskiy', 'standish', 'upernavik', 'sangar', 'sumbe', 'bansko', 'saleaula', 'vila velha', 'khormuj', 'hobyo', 'amuntai', 'ossora', 'harper', 'kelme', 'leningradskiy', 'vestmannaeyjar', 'sentyabrskiy', 'malibu', 'mana', 'hualmay', 'mayumba', 'east london', 'new norfolk', 'ribeira grande', 'geraldton', 'codrington', 'high level', 'ahipara', 'carnarvon', 'tasiilaq', 'rocha', 'longonjo', 'mandurah', 'galle', 'alofi', 'cherskiy', 'kamenskoye', 'beloha', 'impfondo', 'urdzhar', 'batemans bay', 'rundu', 'muroto', 'ajdabiya', 'namibe', 'luderitz', 'lebu', 'lorengau', 'husavik', 'gondar', 'torbay', 'matara', 'taoudenni', 'dicabisagan', 'attawapiskat', 'krizevci', 'imbituba', 'fairbanks', 'khani', 'chengmai', 'zaraza', 'warqla', 'cabo san lucas', 'agadez', 'jalu', 'tabou', 'rajapur', 'lazarev', 'wanning', 'morondava', 'honiara', 'ponta do sol', 'chalchihuites', 'lucea', 'nome', 'san quintin', 'guarapari', 'arraial do cabo', 'westerland', 'ixtapa', 'maceio', 'bambous virieux', 'provideniya', 'prachuap khiri khan', 'korop', 'kavaratti', 'kailua', 'linxia', 'itupiranga', 'saldanha', 'hermagor', 'amderma', 'danville', 'chuy', 'clyde river', 'alpena', 'severo-yeniseyskiy', 'sunnyside', 'santa isabel do rio negro', 'karkaralinsk', 'baghdad', 'praia da vitoria', 'puerto carreno', 'ust-ordynskiy', 'umm ruwabah', 'tuatapere', 'saint-georges', 'avera', 'klaksvik', 'general mamerto natividad', 'alotau', 'katsuura', 'sinnamary', 'olenino', 'tura', 'kenai', 'sesimbra', 'norman wells', 'puerto maldonado', 'chicama', 'doka', 'tiksi', 'porto novo', 'laela', 'winchester', 'zeya', 'zhongxing', 'baft', 'salta', 'taburi', 'canton', 'farafangana', 'palabuhanratu', 'jambi', 'rungata', 'terrace bay', 'pakpattan', 'flinders', 'jefferson city', 'rawson', 'richards bay', 'port-gentil', 'chokwe', 'axim', 'narsaq', 'turayf', 'berlevag', 'beibei', 'teya', 'santiago', 'sechura', 'souillac', 'kurchum', 'russell', 'salalah', 'lolua', 'tautira', 'todos santos', 'hofn', 'sibolga', 'panaba', 'stanger', 'mys shmidta', 'douentza', 'virginia beach', 'thompson', 'krasnovishersk', 'hasaki', 'touros', 'cairns', 'carballo', 'nizhneyansk', 'itaguai', 'beringovskiy', 'raudeberg', 'pisco', 'victoria', 'christchurch', 'ipiau', 'nelson', 'port lincoln', 'rawannawi', 'shelburne', 'yanan', 'karpathos', 'vanino', 'caravelas', 'denpasar', 'camocim', 'cozumel', 'ancud', 'chhabra', 'hun', 'manosque', 'gat', 'shubarshi', 'barranca', 'padang', 'cayenne', 'parana', 'bengkulu', 'el rodeo', 'birao', 'coahuayana', 'kargil', 'fort nelson', 'shahr-e ...

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it's being processed (with the city number and city name).

# %%
print(len(cities))
# Out:
# 612

# %%
url = "https://api.openweathermap.org/data/2.5/weather?"
query_url = url + "appid=" + api_key + "&q=" + city
response = requests.get(query_url).json()

response
# Out:
# {'coord': {'lon': 135.8, 'lat': 34.68},
#  'weather': [{'id': 800,
#    'main': 'Clear',
#    'description': 'clear sky',
#    'icon': '01n'}],
#  'base': 'stations',
#  'main': {'temp': 285.64,
#   'pressure': 1017,
#   'humidity': 93,
#   'temp_min': 284.26,
#   'temp_max': 287.15},
#  'visibility': 8000,
#  'wind': {'speed': 1},
#  'clouds': {'all': 0},
#  'dt': 1556912809,
#  'sys': {'type': 1,
#   'id': 7962,
#   'message': 0.0054,
#   'country': 'JP',
#   'sunrise': 1556913853,
#   'sunset': 1556962978},
#  'id': 1855612,
#  'name': 'Nara',
#  'cod': 200}

# %%
# Query gen function
def querygen(api_key='', city=cities):
    url ='https://api.openweathermap.org/data/2.5/weather'

    return f'{url}?q={city}&appid={api_key}&units=imperial'

# %%
url = "https://api.openweathermap.org/data/2.5/weather?"
#create counter for cities
crec = 0
cmax = len(cities)

query_url = url + "appid=" + api_key + "&q=" + city

#append paramenters
citylist = []
country = []
date = []
lat = []
lon = []
maxtemp = []
humidity = []
clouds = []
wind = []

#pull weather data
for city in cities:
    crec = crec + 1
    response = requests.get(querygen(api_key=api_key, city=city)).json()
    
    try:
        print(f'Processing city {crec} of {cmax}: {response["name"]}')
        citylist.append(response['name'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        lat.append(response['coord']['lat'])
        lon.append(response['coord']['lon'])
        maxtemp.append(response['main']['temp_max'])
        humidity.append(response['main']['humidity'])
        clouds.append(response['clouds']['all'])
        wind.append(response['wind']['speed'])
    except:
        pass
        print(f'Could not find weather for {city}')
    
print(f'-----------------------')
print(f'Data Retrieval Complete')
print(f'-----------------------')
# Out:
# Processing city 1 of 612: Awjilah
# Could not find weather for taolanaro
# Processing city 3 of 612: Ilulissat
# Could not find weather for marcona
# Processing city 5 of 612: Nanortalik
# Processing city 6 of 612: Bredasdorp
# Processing city 7 of 612: Cape Town
# Processing city 8 of 612: Saskylakh
# Processing city 9 of 612: Busselton
# Processing city 10 of 612: Longyearbyen
# Processing city 11 of 612: Islamkot
# Processing city 12 of 612: Bathsheba
# Processing city 13 of 612: Broken Hill
# Processing city 14 of 612: Dunmore Town
# Processing city 15 of 612: Butaritari
# Processing city 16 of 612: Qurbus
# Processing city 17 of 612: Kapaa
# Could not find weather for stornoway
# Processing city 19 of 612: Tecolutla
# Processing city 20 of 612: Barrow
# Processing city 21 of 612: Punta Arenas
# Could not find weather for olafsvik
# Processing city 23 of 612: Atuona
# Processing city 24 of 612: Bethel
# Processing city 25 of 612: Sao Filipe
# Processing city 26 of 612: Iqaluit
# Processing city 27 of 612: Sitka
# Could not find weather for cumaribo
# Processing city 29 of 612: Dikson
# Processing city 30 of 612: Gao
# Processing city 31 of 612: Vardo
# Processing city 32 of 612: Rikitea
# Processing city 33 of 612: Mataura
# Could not find weather for tsihombe
# Processing city 35 of 612: Ushuaia
# Processing city 36 of 612: Sungairaya
# Processing city 37 of 612: Lompoc
# Processing city 38 of 612: Kinkala
# Processing city 39 of 612: Faanui
# Processing city 40 of 612: Okha
# Processing city 41 of 612: Puerto Ayora
# Processing city 42 of 612: Hilo
# Processing city 43 of 612: Kaitangata
# Processing city 44 of 612: Turukhansk
# Processing city 45 of 612: Albany
# Processing city 46 of 612: Winkler
# Processing city 47 of 612: Asekeyevo
# Processing city 48 of 612: Yellowknife
# Could not find weather for mrirt
# Processing city 50 of 612: Manokwari
# Processing city 51 of 612: Avarua
# Processing city 52 of 612: Te Anau
# Processing city 53 of 612: San Patricio
# Processing city 54 of 612: Honningsvag
# Processing city 55 of 612: Hithadhoo
# Processing city 56 of 612: Mar del Plata
# Processing city 57 of 612: Saint George
# Processing city 58 of 612: Jamestown
# Processing city 59 of 612: Airai
# Processing city 60 of 612: Hermanus
# Processing city 61 of 612: Nenjiang
# Processing city 62 of 612: Tezu
# Could not find weather for barentsburg
# Processing city 64 of 612: Pevek
# Processing city 65 of 612: Nikolskoye
# Processing city 66 of 612: Pitimbu
# Processing city 67 of 612: Oistins
# Could not find weather for tabiauea
# Processing city 69 of 612: Bluff
# Processing city 70 of 612: Caiaponia
# Processing city 71 of 612: Hambantota
# Could not find weather for vaitupu
# Processing city 579 of 612: Milkovo
# Processing city 580 of 612: Dingle
# Processing city 581 of 612: Acari
# Processing city 582 of 612: Borovskoy
# Processing city 583 of 612: Bushehr
# Could not find weather for krasnoselkup
# Processing city 585 of 612: Rameswaram
# Processing city 586 of 612: Srednekolymsk
# Processing city 587 of 612: Yinchuan
# Processing city 588 of 612: Mount Isa
# Processing city 589 of 612: Gotemba
# Processing city 590 of 612: Golden
# Processing city 591 of 612: Preobrazheniye
# Processing city 592 of 612: Mount Gambier
# Processing city 593 of 612: Amahai
# Processing city 594 of 612: Shablykino
# Processing city 595 of 612: Hami
# Could not find weather for meyungs
# Processing city 597 of 612: Hailey
# Processing city 598 of 612: Kozhva
# Processing city 599 of 612: Yueyang
# Processing city 600 of 612: Matay
# Processing city 601 of 612: Griffith
# Processing city 602 of 612: Zeliezovce
# Could not find weather for longlac
# Processing city 604 of 612: Mackay
# Processing city 605 of 612: Togur
# Could not find weather for sakakah
# Processing city 607 of 612: Cap Malheureux
# Processing city 608 of 612: Gamba
# Processing city 609 of 612: Indianola
# Processing city 610 of 612: Ugoofaaru
# Processing city 611 of 612: Bandarbeyla
# Processing city 612 of 612: Nara
# -----------------------
# Data Retrieval Complete
# -----------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# create a data frame from cities, & other data
weather_dict = {
    "city": citylist,
    "lat": lat,
    "lon": lon,
    "country": country, 
    "date": date,
    "maxtemp": maxtemp,
    "humidity": humidity,
    "clouds": clouds,
    "wind": wind
}
weather_data = pd.DataFrame(weather_dict)
weather_data.head()
# Out:
#          city    lat    lon country        date  maxtemp  humidity  clouds  \
# 0     Awjilah  29.14  21.30      LY  1556913411    79.79        17      38
# 1   Ilulissat  69.22 -51.10      GL  1556909400    51.80        37      75
# 2  Nanortalik  60.14 -45.24      GL  1556912968    39.83        70     100
# 3  Bredasdorp -34.53  20.04      ZA  1556912739    62.60        59      61
# 4   Cape Town -33.93  18.42      ZA  1556913195    61.00        77      75
#
#     wind
# 0   9.62
# 1  11.41
# 2   6.29
# 3   6.93
# 4   4.70

# %%
weather_data.to_csv(output_data_file)

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
xlat= weather_data['lat']
ytemp = weather_data['maxtemp']
yhumidity = weather_data['humidity']
ycloud = weather_data['clouds']
ywind = weather_data['wind']

# %%
temp_scatter = plt.scatter(xlat, ytemp, marker="o", alpha=0.5, edgecolors="black")

plt.title("City Latitude vs. Max Temperature(05/03/19)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")

plt.savefig("temp_scatter.png")

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
humidity_scatter = plt.scatter(xlat, yhumidity, marker="o", alpha=0.5, edgecolors="black")

plt.title("City Latitude vs. Humidity(05/03/19)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")

plt.savefig("humidity_scatter.png")

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
cloudiness_scatter = plt.scatter(xlat, ycloud, marker="o", alpha=0.5, edgecolors="black")

plt.title("City Latitude vs. Cloudiness(05/03/19)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")

plt.savefig("cloudiness_scatter.png")

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
wind_scatter = plt.scatter(xlat, ywind, marker="o", alpha=0.5, edgecolors="black")

plt.title("City Latitude vs. Wind Speed(05/03/19)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")

plt.savefig("wind_scatter.png")
